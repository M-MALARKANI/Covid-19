# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
covid_df=pd.read_csv('/content/Covid_19_cases4.csv')

# %%
covid_df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories
# 0     31-05-2021   31      5  2021    366       5                 Austria
# 1     30-05-2021   30      5  2021    570       6                 Austria
# 2     29-05-2021   29      5  2021    538      11                 Austria
# 3     28-05-2021   28      5  2021    639       4                 Austria
# 4     27-05-2021   27      5  2021    405      19                 Austria
# ...          ...  ...    ...   ...    ...     ...                     ...
# 2725  06-03-2021    6      3  2021   3455      17                  Sweden
# 2726  05-03-2021    5      3  2021   4069      12                  Sweden
# 2727  04-03-2021    4      3  2021   4884      14                  Sweden
# 2728  03-03-2021    3      3  2021   4876      19                  Sweden
# 2729  02-03-2021    2      3  2021   6191      19                  Sweden
#
# [2730 rows x 7 columns]

# %%
covid_df.head(5)
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories
# 0  31-05-2021   31      5  2021    366       5                 Austria
# 1  30-05-2021   30      5  2021    570       6                 Austria
# 2  29-05-2021   29      5  2021    538      11                 Austria
# 3  28-05-2021   28      5  2021    639       4                 Austria
# 4  27-05-2021   27      5  2021    405      19                 Austria

# %%
plt.figure(figsize=(10, 6))
plt.plot(covid_df['dateRep'], covid_df['day'], label='day', color='blue')
plt.title('COVID-19 Daily Cases')
plt.xlabel('dateRep')
plt.ylabel('day')
plt.legend()
plt.grid()
plt.xticks(rotation=20)
plt.show()

# %%
min_value = 3
max_value = 10

# Filter the data to only include values within the specified range


# Create a histogram for the filtered data
plt.hist(covid_df, bins=5, edgecolor='black')
plt.xlabel('dateRep')
plt.ylabel('day')
plt.title('Covid_19')

# Display the histogram
plt.show()
